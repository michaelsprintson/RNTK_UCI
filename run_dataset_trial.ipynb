# %%
# %load_ext line_profiler
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import jax.numpy as jnp
import old.tools, old.RNTK_avg
import jax
import symjax
import symjax.tensor as T
import copy
import time

from RNTK_onediag_dual import RNTK as RNTKOD_dual
from RNTK_onediag_dual import create_func as create_func_dual

# %%
# dataset = "trains"
# dataset = "bank"

# %%
# dic = {k:v for k,v in map(lambda x : x.split(), open("data" + "/" + dataset + "/" + dataset + ".txt", "r").readlines())}
dic = {}

# %%
def run_and_test(dic):
    diag_func, rntk_dual = create_func_dual(dic, True)
    fake_data_ti = np.zeros((dic["n_patrons1="],dic["n_entradasTi="]))
    fake_data_tiprime = np.zeros((dic["n_patrons1="],dic["n_entradasTiP="]))
    start = time.time()
    result = diag_func(fake_data_ti, fake_data_tiprime)
    # # gp_kernel = result[0]
    # # rntk_kernel = result[1]
    print("time to compute ", time.time() - start)
    return result

# %%
import json

# %%
# results = {}

for ti in range(2,15,1):
    for tip in range(13,15,1):

        dic["n_patrons1="] = 10#00 #// N (what affect symjax time)
        dic["n_entradasTiP="] = tip#00 #// TiPrime length
        dic["n_entradasTi="] = ti#00 #// Ti length (multiplier on symjax time)
        #UCR dataset of about this size
        result = run_and_test(dic)
        array_sum = np.sum(result)
        array_has_nan = np.isnan(array_sum)
        # print(result.shape)
        with open("timings10.txt", "a") as file:
            json.dump({f"{ti},{tip}": int(array_has_nan)}, file, indent=1)
        with open("results10.txt", "a") as file:
            json.dump({f"{ti},{tip}": result.tolist()}, file, indent=1)
        # results[] = result
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# time to create symjax 0.6667227745056152
# time to compute  0.8833847045898438
# time to create symjax 0.9931418895721436
# time to compute  1.27016282081604
# time to create symjax 1.510202169418335
# time to compute  1.6632630825042725
# time to create symjax 2.1916658878326416
# time to compute  2.1552770137786865
# time to create symjax 2.9860968589782715
# time to compute  2.6220059394836426
# time to create symjax 3.7050061225891113
# time to compute  3.1935741901397705
# time to create symjax 4.636419057846069
# time to compute  3.721614122390747
# time to create symjax 5.567939043045044
# time to compute  4.391061067581177
# time to create symjax 6.738285064697266
# time to compute  5.169661045074463
# time to create symjax 7.851107835769653
# time to compute  5.9708380699157715
# time to create symjax 9.287014245986938
# time to compute  6.825728893280029
# time to create symjax 10.975590944290161
# time to compute  7.969395875930786
# time to create symjax 12.599610805511475
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/jl/s6y0f3250_b1k50q9f44tpj40000gn/T/ipykernel_9984/290036158.py in <module>
#       8         dic["n_entradasTi="] = ti#00 #// Ti length (multiplier on symjax time)
#       9         #UCR dataset of about this size
# ---> 10         result = run_and_test(dic)
#      11         array_sum = np.sum(result)
#      12         array_has_nan = np.isnan(array_sum)
#
# /var/folders/jl/s6y0f3250_b1k50q9f44tpj40000gn/T/ipykernel_9984/1773879967.py in run_and_test(dic)
#       4     fake_data_tiprime = np.zeros((dic["n_patrons1="],dic["n_entradasTiP="]))
#       5     start = time.time()
# ----> 6     result = diag_func(fake_data_ti, fake_data_tiprime)
#       7     # # gp_kernel = result[0]
#       8     # # rntk_kernel = result[1]
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in __call__(self, device_get, *args)
#    1079         # key, otherwise each function call returns the same realisation
#    1080
# -> 1081         outputs = self.meta(*args)
#    1082
#    1083         if device_get:
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in meta(*fnargs)
#    1060                 self.updates_keys + self.extra_inputs, tracker={}
#    1061             )
# -> 1062             jitoutputs, jitupdates = self.jited(*fnargs, *jited_add_inputs)
#    1063             for key, update in zip(self.updates_keys, jitupdates):
#    1064                 key.update(update)
#
#     [... skipping hidden 1 frame]
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     397       _check_arg(arg)
#     398     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 399     out_flat = xla.xla_call(
#     400         flat_fun, *args_flat,
#     401         device=device, backend=backend, name=flat_fun.__name__,
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1559
#    1560   def bind(self, fun, *args, **params):
# -> 1561     return call_bind(self, fun, *args, **params)
#    1562
#    1563   def process(self, trace, fun, tracers, params):
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1550       params_tuple, out_axes_transforms)
#    1551   tracers = map(top_trace.full_raise, args)
# -> 1552   outs = primitive.process(top_trace, fun, tracers, params)
#    1553   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1554
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1562
#    1563   def process(self, trace, fun, tracers, params):
# -> 1564     return trace.process_call(self, fun, tracers, params)
#    1565
#    1566   def post_process(self, trace, out_tracers, params):
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     605
#     606   def process_call(self, primitive, f, tracers, params):
# --> 607     return primitive.impl(f, *tracers, **params)
#     608   process_map = process_call
#     609
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(***failed resolving arguments***)
#     605                    donated_invars, inline):
#     606   del inline  # Only used at tracing time
# --> 607   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     608                                *unsafe_map(arg_spec, args))
#     609   try:
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     260       fun.populate_stores(stores)
#     261     else:
# --> 262       ans = call(fun, *args)
#     263       cache[key] = (ans, fun.stores)
#     264
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     680
#     681   abstract_args, arg_devices = unzip2(arg_specs)
# --> 682   jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(
#     683       fun, abstract_args, pe.debug_info_final(fun, "jit"))
#     684   if any(isinstance(c, core.Tracer) for c in consts):
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals, debug_info)
#    1283     main.jaxpr_stack = ()  # type: ignore
#    1284     with core.new_sublevel():
# -> 1285       jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1286     del fun, main
#    1287   return jaxpr, out_avals, consts
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1261     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1262     in_tracers = map(trace.new_arg, in_avals)
# -> 1263     ans = fun.call_wrapped(*in_tracers)
#    1264     out_tracers = map(trace.full_raise, ans)
#    1265     jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in to_jit(*jitargs)
#    1029             #            feed_dict.update({"rng": seed})
#    1030             outputs = [self.outputs, self.updates_values]
# -> 1031             return symjax.current_graph().get(outputs, feed_dict)
#    1032
#    1033         # take care of the presence of -1 dimensions
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in get(self, item, tracker, frozen)
#     259         """
#     260         tracker = {} if tracker is None else tracker
# --> 261         value = self._get(item, tracker, frozen)
#     262         # if isinstance(value, jax.interpreters.xla.DeviceArray):
#     263         #     return jax.device_get(value)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in _get(self, item, tracker, frozen)
#     283
#     284         if type(item) == list:
# --> 285             return [self.get(i, tracker, frozen=frozen) for i in item]
#     286
#     287         elif type(item) == tuple:
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in <listcomp>(.0)
#     283
#     284         if type(item) == list:
# --> 285             return [self.get(i, tracker, frozen=frozen) for i in item]
#     286
#     287         elif type(item) == tuple:
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in get(self, item, tracker, frozen)
#     259         """
#     260         tracker = {} if tracker is None else tracker
# --> 261         value = self._get(item, tracker, frozen)
#     262         # if isinstance(value, jax.interpreters.xla.DeviceArray):
#     263         #     return jax.device_get(value)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in _get(self, item, tracker, frozen)
#     309             # first get the actual parents nodes (aka inputs to the function)
#     310
# --> 311             args, kwargs = self.get_args_kwargs(item, tracker, frozen=frozen)
#     312
#     313             tracker[item] = self.nodes[item]["jax_function"](*args, **kwargs)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in get_args_kwargs(self, node, tracker, evaluate, frozen)
#     349             all_args = {}
#     350             for i in range(len(parents)):
# --> 351                 all_args[self[parents[i]][node]["name"]] = self.get(
#     352                     parents[i], tracker, frozen=frozen
#     353                 )
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in get(self, item, tracker, frozen)
#     259         """
#     260         tracker = {} if tracker is None else tracker
# --> 261         value = self._get(item, tracker, frozen)
#     262         # if isinstance(value, jax.interpreters.xla.DeviceArray):
#     263         #     return jax.device_get(value)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in _get(self, item, tracker, frozen)
#     303         elif type(item) == t.OpItem:
#     304
# --> 305             return self.get(item.parent, tracker)[item.parent_index]
#     306
#     307         elif isinstance(item, t.Op):
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in get(self, item, tracker, frozen)
#     259         """
#     260         tracker = {} if tracker is None else tracker
# --> 261         value = self._get(item, tracker, frozen)
#     262         # if isinstance(value, jax.interpreters.xla.DeviceArray):
#     263         #     return jax.device_get(value)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in _get(self, item, tracker, frozen)
#     311             args, kwargs = self.get_args_kwargs(item, tracker, frozen=frozen)
#     312
# --> 313             tracker[item] = self.nodes[item]["jax_function"](*args, **kwargs)
#     314             return tracker[item]
#     315
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/tensor/control_flow.py in _scan(f, init, sequences, non_sequences, length, reverse)
#      23             return truef(a, *args, *non_sequences)
#      24
# ---> 25     return jla.scan(finalf, init, sequences, length=length, reverse=reverse)
#      26
#      27
#
#     [... skipping hidden 1 frame]
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/_src/lax/control_flow.py in scan(f, init, xs, length, reverse, unroll)
#    1286   # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#    1287   # necessary, a second time with modified init values.
# -> 1288   init_flat, carry_avals, carry_avals_out, init_tree, *rest = _create_jaxpr(init)
#    1289   new_init_flat, changed = _promote_weak_typed_inputs(init_flat, carry_avals, carry_avals_out)
#    1290   if changed:
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/_src/lax/control_flow.py in _create_jaxpr(init)
#    1272
#    1273     carry_avals = tuple(_map(_abstractify, init_flat))
# -> 1274     jaxpr, consts, out_tree = _initial_style_jaxpr(
#    1275         f, in_tree, carry_avals + x_avals, "scan")
#    1276     out_tree_children = out_tree.children()
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/_src/util.py in wrapper(*args, **kwargs)
#     184         return f(*args, **kwargs)
#     185       else:
# --> 186         return cached(config._trace_context(), *args, **kwargs)
#     187
#     188     wrapper.cache_clear = cached.cache_clear
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/_src/util.py in cached(_, *args, **kwargs)
#     177     @functools.lru_cache(max_size)
#     178     def cached(_, *args, **kwargs):
# --> 179       return f(*args, **kwargs)
#     180
#     181     @functools.wraps(f)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/_src/lax/control_flow.py in _initial_style_jaxpr(fun, in_tree, in_avals, primitive_name)
#      74 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals,
#      75                          primitive_name: Optional[str] = None):
# ---> 76   jaxpr, consts, out_tree = _initial_style_open_jaxpr(
#      77       fun, in_tree, in_avals, primitive_name)
#      78   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/_src/util.py in wrapper(*args, **kwargs)
#     184         return f(*args, **kwargs)
#     185       else:
# --> 186         return cached(config._trace_context(), *args, **kwargs)
#     187
#     188     wrapper.cache_clear = cached.cache_clear
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/_src/util.py in cached(_, *args, **kwargs)
#     177     @functools.lru_cache(max_size)
#     178     def cached(_, *args, **kwargs):
# --> 179       return f(*args, **kwargs)
#     180
#     181     @functools.wraps(f)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/_src/lax/control_flow.py in _initial_style_open_jaxpr(fun, in_tree, in_avals, primitive_name)
#      68   wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
#      69   debug = pe.debug_info(fun, in_tree, False, primitive_name or "<unknown>")
# ---> 70   jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals, debug)
#      71   return jaxpr, consts, out_tree()
#      72
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_dynamic(fun, in_avals, debug_info)
#    1251     main.debug_info = debug_info  # type: ignore
#    1252     main.jaxpr_stack = ()  # type: ignore
# -> 1253     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1254     del main, fun
#    1255   return jaxpr, out_avals, consts
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1261     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1262     in_tracers = map(trace.new_arg, in_avals)
# -> 1263     ans = fun.call_wrapped(*in_tracers)
#    1264     out_tracers = map(trace.full_raise, ans)
#    1265     jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/tensor/control_flow.py in finalf(a, args)
#      21
#      22         def finalf(a, args):
# ---> 23             return truef(a, *args, *non_sequences)
#      24
#      25     return jla.scan(finalf, init, sequences, length=length, reverse=reverse)
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/tensor/base.py in newfn(fn, *args)
#     887     def newfn(*args, fn=func):
#     888         pholders = placeholder_like(args)
# --> 889         symjax_outputs = fn(*pholders)
#     890         feed_dict = {}
#     891         match(pholders, args, feed_dict)
#
# ~/Documents/nosync.nosync/richb-code/RNTK_UCI/RNTK_onediag_dual.py in fn(prev_vals, idx, data_idxs, DATAPH, DATAPRIMEPH, qtph, qtprimeph)
#     181             # print(qtph[data_idxs[0][1] - 1])
#     182             # print(qtprimeph[data_idxs[0][0] - 1])
# --> 183             S, D = self.alg2_VT(qtph[data_idxs[0][1] - 1], qtprimeph[data_idxs[0][0] - 1] ,prev_lambda)
#     184             new_lambda = self.sw ** 2 * S + self.su ** 2 * xINNER + self.sb ** 2 ## took out an X
#     185             new_phi = new_lambda + self.sw ** 2 * prev_phi * D
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/tensor/base.py in wrapper(self, *args, **kwargs)
#      48         @wraps(func)
#      49         def wrapper(self, *args, **kwargs):
# ---> 50             return func(self, *args, **kwargs)
#      51
#      52         if name == "":
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/tensor/base.py in op(seed, *args, **kwargs)
#     245                 return RandomOp(*args, _seed=seed, **feed, **kwargs)
#     246             else:
# --> 247                 return Op(*args, **feed, **kwargs)
#     248
#     249     symjax._fn_to_op[func] = op
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/tensor/base.py in __init__(self, _jax_function, _shape, _dtype, name, *args, **kwargs)
#     454             name = _jax_function.__name__
#     455
# --> 456         name, scope = symjax.current_graph()._get_name_scope(name, self)
#     457
#     458         super().__init__(
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in _get_name_scope(self, name, tensor)
#      70
#      71     def _get_name_scope(self, name, tensor):
# ---> 72         return self.scope._get_name_scope(name, tensor)
#      73
#      74     def is_connected(self, node_1, node_2, directed=True):
#
# ~/Documents/nosync.nosync/richb-code/rntk-env/lib/python3.8/site-packages/symjax/base.py in _get_name_scope(self, name, tensor)
#     554                 return nodes[nodes.index(tensor)]
#     555             count = 1
# --> 556             while test_name + "_" + str(count) in names:
#     557                 count += 1
#     558             return name + "_" + str(count), self.absolute_name
#
# KeyboardInterrupt:

# %%
# diag_func, rntk_dual = create_func_dual(dic, True)

# %% [markdown]
# lets execute the symjax

# %%
# fake_data_ti = np.zeros((dic["n_patrons1="],dic["n_entradasTi="]))
# fake_data_tiprime = np.zeros((dic["n_patrons1="],dic["n_entradasTiP="]))

# %%
# start = time.time()
# result = diag_func(fake_data_ti, fake_data_tiprime)
# # # gp_kernel = result[0]
# # # rntk_kernel = result[1]
# print(time.time() - start)
# result

# %%
# %%timeit
# diag_func(fake_data)
